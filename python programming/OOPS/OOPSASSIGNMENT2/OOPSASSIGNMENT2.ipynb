# %% [markdown]
# # Constructor:

# %%
#5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an
#   example of creating an object of this class.


class person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

obj = person('lucifer',23)
print('name:',obj.name)
print('age:',obj.age)
# Out:
# name: lucifer
# age: 23

# %%
#9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height`
#   attributes. Provide a method to calculate the area of the rectangle.


class rectangle:

  def __init__(self,width,height):
    self.width = width
    self.height = height

  def area(self):
    print('width =',self.width)
    print('height =',self.height)
    print('area of rectangle =',self.width*self.height)

# %%
obj1 = rectangle(4,6)

# %%
obj1.area()
# Out:
# width = 4
# height = 6
# area of rectangle = 24

# %%
#10. How can you have multiple constructors in a Python class? Explain with an example.

class calculator:

  def __init__(self):
    print('sum of 1 and 2 is 3')

  def __init__(self):
    print('sum of 2 and 3 is 5')

  def __init__(self):
    print('sum of 3 and 4 is 7')

luci = calculator()
# Out:
# sum of 3 and 4 is 7

# %%
#11. What is method overloading, and how is it related to constructors in Python?

class list_ops:

  def __init__(self,l):
    self.l1=l
    self.l2=40
    self.l3='luci'
    self.l4=(4,5,6,6,7,8)
    self.l5={'key':'value'}

  def extractfromindex(self, l , index):
    return l[index]

  def extractrangedate(self,l,start,end):
    return l[start:end]

  def extracteven(self,l):
    l1=[]
    for i in l:
      if i%2==0:
        l1.append(i)
    return l1

second_obj=list_ops([3,4,5,6,7,8])
print(second_obj.l2)
second_obj.extracteven([12,3,44,55,67,66])
# Out:
# 40
# [12, 44, 66]

# %%
#12. Explain the use of the `super()` function in Python constructors. Provide an example.

class human:

  def __init__(self):
    pass

  def eat(self):
    print('print the eat method from human')

class male(human):
  def __init__(self,name):
    self.name = name

  def eat(self):
    super().eat()
    print(self.name)

luci = male('lucifer')
luci.eat()
# Out:
# print the eat method from human
# lucifer

# %%
#13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year`
#    attributes. Provide a method to display book details.


class Book:
   def __init__(self,title,author,published_year):
    self.title = title
    self.author = author
    self.published_year = published_year

   def details(self):
    print('book details:',self.title,',',self.author,',',self.published_year)

obj3 = Book('life matters','Diago',1997)
obj3.details()
# Out:
# book details: life matters , Diago , 1997

# %%
#16. How do you prevent a class from having multiple instances by using constructors in Python? Provide an example.

class calculation:

  @staticmethod
  def add(x,y):
    return x+y

  @staticmethod
  def sub(x,y):
    return x-y

  def div(self,x,y):
    return x/y

class cal(calculation):
  pass

c1 = cal()
c1.div(4,5)
# Out:
# 0.8

# %%
#17. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and
#    initializes the `subjects` attribute.


class Student:
   def __init__(self):
        self.add = list()

   def build(self,subjects):
        self.add.append(subjects)


obj1 = Student()
a1 = ["data science,full stock,Java,python"]
for a in a1:
    split_values = a.split(",")
    obj1.build(split_values)

print (obj1.add)
# Out:
# [['data science', 'full stock', 'Java', 'python']]

# %%
#19. Explain the use of constructor chaining in Python. Provide a practical example.


class Human(object):
    def __init__(self):
        print("Hi this is Human Constructor")

class Man(Human):
    def __init__(self):
        super(Man, self).__init__()
        print("Hi this is Man Constructor")

class Woman(Human):
    def __init__(self):
        super(Woman, self).__init__()
        print("Hi this is Woman Constructor")

# %%
#20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model`
#    attributes. Provide a method to display car information.


class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model
    def details(self):
        print ('information about car:',self.make,',', self.model)

rudra = Car('tesla','model 3')
rudra.details()
# Out:
# information about car: tesla , model 3

# %% [markdown]
# # Inheritance:

# %%
#3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called
#   `Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object.


class vehicle:

  def __init__(self,color,speed):
    self.colour = color
    self.speed = speed

  def display(self):
    print(self.colour,self.speed)

class car(vehicle):

  def __init__(self,color,speed,brand):
    super().__init__(color,speed)
    self.brand = brand

  def display1(self):
    print('colour-',self.colour,'\nspeed-',self.speed,'\nbrand-',self.brand)


luci = car('red',123,'tesla')
luci.display1()
# Out:
# colour- red
# speed- 123
# brand- tesla

# %%
#4. Explain the concept of method overriding in inheritance. Provide a practical example.


class Parent1():

    def show(self):
        print("Inside Parent1")

class Parent2():

    def display(self):
        print("Inside Parent2")


class Child(Parent1, Parent2):

    def show1(self):
        super().show()
        super().display()
        print("Inside Child")


obj = Child()

obj.show1()
# Out:
# Inside Parent1
# Inside Parent2
# Inside Child

# %%
#5. How can you access the methods and attributes of a parent class from a child class in Python? Give an example.

class human:

  def __init__(self):
    pass

  def eat(self):
    print('print the eat method from human')

class male(human):
  def __init__(self,name):
    self.name = name

  def eat(self):
    super().eat()
    print(self.name)

obj = male('aldiago')
obj.eat()
# Out:
# print the eat method from human
# aldiago

# %%
#6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an example.

class pwskills:

   def __init__(self,mentor):
    self.mentor = mentor

   def mentor_name(self):
    print(self.mentor)

class datascience(pwskills):

   def __init__(self,mentor,mentor_mail_id):
    super().__init__(mentor)
    self.mentor_mail_id= mentor_mail_id

   def show_info(self):
    super().mentor_name()
    print(self.mentor,self.mentor_mail_id)

python_basic = datascience('aldiago','aldiago12@gmail.com')
python_basic.show_info()
# Out:
# aldiago
# aldiago aldiago12@gmail.com

# %%
#7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat` that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes.


class Animal:

  def speak(self):
    print('inside animal')

class Dog(Animal):

  def speak(self):
     print('inside dog')

class Cat(Animal):

  def speak(self):
     print('inside cat')

obj1 = Dog()
obj2 = Cat()
obj1.speak()
obj2.speak()
# Out:
# inside dog
# inside cat

# %%
#8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance.

class study:
    course = 'DSA'

    def purchase(obj):
        return obj.course

study.purchase = classmethod (study.purchase)
str(isinstance (study.purchase(), str))
# Out:
# 'True'

# %%
#9. What is the purpose of the `issubclass()` function in Python? Provide an example.

class myAge:
  age = 36

class myObj(myAge):
  name = "luci"
  age = myAge

x = issubclass(myObj, myAge)

print(x)
# Out:
# True

# %%
#11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method
#    accordingly. Provide an example.


import math


class Shape:

    def calculate_area(self):
        pass


class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2


class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width


circle = Circle(5)
print('Area of Circle:',circle.calculate_area())

rectangle = Rectangle(5,7)
print('Area of rectangle:',rectangle.calculate_area())
# Out:
# Area of Circle: 78.53981633974483
# Area of rectangle: 35

# %%
#12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the `abc` module.


import abc


class AbstractClass(metaclass=abc.ABCMeta):
    def abstractfunc(self):
        return None


AbstractClass.register(dict)
print(issubclass(dict, AbstractClass))
# Out:
# True

# %%
#14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class
#    `Manager` that inherits from `Employee` and adds an attribute `department`. Provide an example.


class Employee:

   def __init__(self,name,salary):
    self.name = name
    self.salary = salary

   def emp_details(self):
    print(self.name)
    print(self.salary)

class Manager(Employee):

   def __init__(self,name,salary,department):
    super().__init__(name,salary)
    self.department = department

   def show_info(self):
    print(self.name,'\n',self.salary,'\n',self.department)

employee34 = Manager('aldiago',34000,'security')
employee34.show_info()
# Out:
# aldiago
#  34000
#  security

# %%
#16. Explain the purpose of the `__init__()` method in Python inheritance and how it is utilized in child classes.

class pwskills:

   def __init__(self,mentor):
    self.mentor = mentor

   def mentor_name(self):
    print(self.mentor)

class datascience(pwskills):

   def __init__(self,mentor,mentor_mail_id):
    super().__init__(mentor)
    self.mentor_mail_id= mentor_mail_id

   def show_info(self):
    super().mentor_name()
    print(self.mentor,self.mentor_mail_id)

python_basic = datascience('aldiago','aldiago12@gmail.com')
python_basic.show_info()
# Out:
# aldiago
# aldiago aldiago12@gmail.com

# %%
#17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow` that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these classes.


class Bird:

  def __init__(self):
     pass

  def fly(self):
    print('Bird is flying')

class Eagle(Bird):

   def __init__(self):
    pass

   def fly(self):
    print('Eagle is under bird ')

class Sparrow(Bird):

    def __init__(self):
      pass

    def fly(self):
      super().fly()
      print('Sparrow is under bird')

animal1 = Eagle()
animal2 = Sparrow()
animal1.fly()
animal2.fly()
# Out:
# Eagle is under bird
# Bird is flying
# Sparrow is under bird

# %%
# 18. What is the "diamond problem" in multiple inheritance, and how does Python address it?


class Class1:
    def m(self):
        print("In Class1")

class Class2(Class1):
    def m(self):
        print("In Class2")

class Class3(Class1):
    def m(self):
        print("In Class3")

class Class4(Class2, Class3):
    pass

obj = Class4()
obj.m()
# Out:
# In Class2

# %%
#20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create child
#    classes `Student` and `Professor`, each with their own attributes and methods. Provide an example of using
#    these classes in a university context.

class Person:

  def __init__(self,name,email_id):
    self.name = name
    self.email_id = email_id

  def show(self):
    print(self.name,self.email_id)

class Student(Person):

  def __init__(self,name,email_id,student_id,department):
    super().__init__(name,email_id)
    self.student_id = student_id
    self.department = department

  def stu_details(self):
    print('student name-',self.name,'\nstudent email-',self.email_id,'\nstudent id-',self.student_id,'\ndepartment-',self.department)

class Professor(Person):

  def __init__(self, name, email_id,professor_id,prof_department):
     super().__init__(name, email_id)
     self.professor_id = professor_id
     self.prof_department = prof_department

  def proff_details(self):
    print('Professor name-',self.name,'\nProfessor email-',self.email_id,'\nProfessor id-',self.professor_id,'\nProfessor dep-',self.prof_department)


obj2 = Student('Lucifer','luci@gmail.com','All345677','IT')
obj2.stu_details()
obj3 = Professor('TOM','tom@gmail.com','AJD34566','IT')
obj3.proff_details()
# Out:
# student name- Lucifer
# student email- luci@gmail.com
# student id- All345677
# department- IT
# Professor name- TOM
# Professor email- tom@gmail.com
# Professor id- AJD34566
# Professor dep- IT

# %% [markdown]
# # Encapsulation:

# %%
#5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the
#   name attribute.


class Person:

  def __init__(self,name):
    self.__name = name

  def show(self):
    print('name-',self.__name)

obj1=Person('luci')
obj1._Person__name
# Out:
# 'luci'

# %%
# 6. Explain the purpose of getter and setter methods in encapsulation. Provide examples.


class X:
    def __init__(self, age = 0):
         self._age = age

    def get_age(self):
        return self._age

    def set_age(self, a):
        self._age = a

raj = X()


raj.set_age(21)

print(raj.get_age())

print(raj._age)
# Out:
# 21
# 21

# %%
# 8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`)


class BankAccount:
    def __init__(self,account_number,balance):
        self.__balance= balance
        self.__account_number= account_number
        print("Hello!!! Welcome to the Deposit & Withdrawal Machine")

    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.__balance += amount
        print("\n Amount Deposited:",amount)

    def withdraw(self):
        amount = float(input("Enter amount to be Withdrawn: "))
        if self.__balance>=amount:
            self.__balance-=amount
            print("\n You Withdrew:", amount)
        else:
            print("\n Insufficient balance  ")

    def display(self):
        print("\n Net Available Balance=",self.__balance)

s = BankAccount('Al234567',5678905)

s.deposit()
s.withdraw()
s.display()
# Out:
# Hello!!! Welcome to the Deposit & Withdrawal Machine
# Enter amount to be Deposited: 4567
#
#  Amount Deposited: 4567.0
# Enter amount to be Withdrawn: 5678
#
#  You Withdrew: 5678.0
#
#  Net Available Balance= 5677794.0

# %%
#10. How can you access private attributes in Python? Provide an example demonstrating the use of name mangling.

class Professor:
    def __init__(self, name):
        self.__name = name

s1 = Professor("luci")
print(s1._Professor__name)
# Out:
# luci

# %%
# 11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses,
#      and implement encapsulation principles to protect sensitive information.


class School:

   def __init__(self):
    pass

class Students(School):

   def __init__(self,stu_name,stu_id):
    self.__stu_name = stu_name
    self.__stu_id = stu_id

   def show(self):
     print('Student name-',self.__stu_name,'\nStudent id-',self.__stu_id )

class Teachers(School):

   def __init__(self,prof_name,prof_id):
    self.__prof_name = prof_name
    self.__prof_id = prof_id

   def show2(self):
    print('Teacher name-',self.__prof_name,'\nTeacher id-',self.__prof_id)

class Courses(School):

   def __init__(self,cour_name):
    self.__cour_name = cour_name

   def show3(self):
    print('Courses name-',self.__cour_name)

w = Students('sachin','asd345667')
e = Teachers('Ravi','we1234345')
r = Courses('ALL ')

w.show()
e.show2()
r.show3()
# Out:
# Student name- sachin
# Student id- asd345667
# Teacher name- Ravi
# Teacher id- we1234345
# Courses name- ALL

# %%
#12. Explain the concept of property decorators in Python and how they relate to encapsulation.

class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius

    @property
    def celsius(self):
        return self._celsius

    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32

temp = Temperature(34)
print(temp.celsius)
print(temp.fahrenheit)
# Out:
# 34
# 93.2

# %%
#13. What is data hiding, and why is it important in encapsulation? Provide examples.

class S:
    __privateCounter = 0

    def total(self):
        self.__privateCounter += 1
        print(self.__privateCounter)


count = S()
count.total()
count.total()

print(count._S__privateCounter)
# Out:
# 1
# 2
# 2

# %%
#14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`).provide a method to calculate yearly bonuses.

class Employee:

  def __init__(self,name,employee_id,salary):
    self.__name = name
    self.__employee_id = employee_id
    self.__salary = salary

  def Bonuses(self,salary,hours_worked):
      __overtime = 0
      if hours_worked > 50:
          self.__overtime = hours_worked - 50
      self.__salary = self.__salary + (self.__overtime * (self.__salary / 50))
      print(self.__salary)

s = Employee('Lucifer','AL123444',34000)
s.Bonuses(34000,56)
print('Salary-',s._Employee__salary)
# Out:
# 38080.0
# Salary- 38080.0

# %%
#17. Create a Python class for a library system that encapsulates book information, including titles, authors,  and availability status.




class library:

  def __init__(self, title, author):
     self.__title = title
     self.__author = author


  def inform(self):
    if  self.__title == ('arabic'):
      print('Titile of the book-',self.__title)
      print('Author-',self.__author)
      print('Available')
    else:
      print('Not Available')

w = library('atygh','luci')
w.inform()
# Out:
# Not Available

# %%
#20. Create a Python class called `Customer` with private attributes for customer details like name, address,
#    and contact information. Implement encapsulation to ensure data integrity and security.

class Customer:

  def __init__(self,name, address,contact_no):
     self.__name = name
     self.__address = address
     self.__contact_no = contact_no




w = Customer('luci','los angles','645737389')
print(w._Customer__name)
print(w._Customer__address)
print(w._Customer__contact_no)
# Out:
# luci
# los angles
# 645737389

# %% [markdown]
# # Polymorphism:

# %%
#3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism
#   through a common method, such as `calculate_area()`.


import math


class Shape:

    def calculate_area(self):
        pass



class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius


    def calculate_area(self):
        return math.pi * self.radius**2


class Square(Shape):

    def __init__(self, length):
        self.length = length


    def calculate_area(self):
        return self.length**2



class Triangle(Shape):

    def __init__(self, base, height):
        self.base = base
        self.height = height



    def calculate_area(self):
        return 0.5 * self.base * self.height



r = 7
circle = Circle(r)
circle_area = circle.calculate_area()
print("Radius of the circle:", r)
print("Circle Area:", circle_area)



l = 5
square = Square(l)
square_area = square.calculate_area()
print("\nSquare: Length (l)=", l,)
print(" Square of l :", square_area)



base = 5
height = 4
print("\nTriangle: Base =", base, " Height =", height)
triangle = Triangle(base, height, )
triangle_area = triangle.calculate_area()

print("Triangle Area:", triangle_area)
# Out:
# Radius of the circle: 7
# Circle Area: 153.93804002589985
#
# Square: Length (l)= 5
#  Square of l : 25
#
# Triangle: Base = 5  Height = 4
# Triangle Area: 10.0

# %%
#4. Explain the concept of method overriding in polymorphism. Provide an example.

class pwskills:
  def student(self):
    pass

class datascience(pwskills):
  def student(self):
    print('this will give me a details about data science student')

class bigdata(pwskills):
  def student(self):
    print('this will give me a datails about big data student')

lucifer = datascience()
aldiago=bigdata()
lucifer.student()
aldiago.student()
# Out:
# this will give me a details about data science student
# this will give me a datails about big data student

# %%
# 6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`, each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method
#    on objects of different subclasses.


class Animal:

  def speak(self):
    print('inside animal')

class Dog(Animal):

  def speak(self):
     print('inside dog')

class Cat(Animal):

  def speak(self):
     print('inside cat')

class Bird(Animal):

  def speak(self):
     print('inside bird')

obj1 = Dog()
obj2 = Cat()
obj3 = Bird()
obj1.speak()
obj2.speak()
obj3.speak()
# Out:
# inside dog
# inside cat
# inside bird

# %%
# 7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example
#    using the `abc` module.


import abc


class AbstractClass(metaclass=abc.ABCMeta):
    def abstractfunc(self):
        return None


AbstractClass.register(dict)
print(issubclass(dict, AbstractClass))
# Out:
# True

# %%
#8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` method that prints a message specific to each vehicle type.


class vehicle:

  def __init__(self,color,speed):
    self.colour = color
    self.speed = speed

  def start(self):
    print('Car,Bicycle,Boat')

class car(vehicle):

  def __init__(self,color,speed):
    super().__init__(color,speed)
    self.colour = color
    self.speed = speed

  def start(self):
    print("Drive!")

class bicycle(vehicle):
  def __init__(self, color, speed):
    self.colour = color
    self.speed = speed

  def start(self):
    print("Ride!")

class boat(vehicle):
  def __init__(self, color, speed):
    self.colour = color
    self.speed = speed

  def start(self):
    print("Sail!")


car1 = car('red','123km')
bicycle1 = bicycle('green','67km')
boat1 = boat('white','50km')

for x in (car1,bicycle1,boat1):
  x.start()
# Out:
# Drive!
# Ride!
# Sail!

# %%
#11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle).


import math


class Shape:

    def calculate_area(self):
        pass


class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2


class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width


class Triangle(Shape):

    def __init__(self, base, height):
        self.base = base
        self.height = height



    def calculate_area(self):
        return 0.5 * self.base * self.height



circle = Circle(5)
print('Area of Circle:',circle.calculate_area())

rectangle = Rectangle(5,7)
print('Area of rectangle:',rectangle.calculate_area())

triangle = Triangle(5,7 )
print('Area of triangle:',triangle.calculate_area())
# Out:
# Area of Circle: 78.53981633974483
# Area of rectangle: 35
# Area of triangle: 17.5

# %%
#13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent classes?


class pwskills:
  def __init__(self):
    pass
  def student(self):
    print('this is pwskills student')

class datascience(pwskills):
  def student(self):
    super().student()
    print('this will give me a dtails about datascience')

messi = datascience()
messi.student()
# Out:
# this is pwskills student
# this will give me a dtails about datascience

# %%
#14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking,



class BankAccount:
    def __init__(self):
        pass

class Savings(BankAccount):

    def __init__(self,balance):
     self.balance= balance


    def withdraw(self):
      print("Hello!!! Welcome to the ABC bank")
      amount = float(input("Enter amount to be Withdrawn: "))
      if self.balance>=amount:
          self.balance-=amount
          print("\n You Withdrew:", amount)
      else:
          print("\n Insufficient balance  ")
      print("\n Net Available Balance=",self.balance)

class Checking(BankAccount):

    def __init__(self,balance):
     self.balance= balance

    def withdraw(self):
      print("Hello!!! Welcome to the ABC bank Check service")
      amount = float(input("Enter amount to be Withdrawn: "))
      if self.balance>=amount:
          self.balance-=amount
          print("\n You Withdrew:", amount)
      else:
          print("\n Insufficient balance  ")
      print("\n Net Available Balance=",self.balance)

class Credit_card(BankAccount):
    def __init__(self,balance):
     self.balance= balance


    def withdraw(self):
      print("Hello!!! Welcome to the ABC bank Credit Card service")
      amount = float(input("Enter amount to be Withdrawn: "))
      if self.balance>=amount:
          self.balance-=amount
          print("\n You Withdrew:", amount)
      else:
          print("\n Insufficient balance  ")
      print("\n Net Available Balance=",self.balance)


luci = Savings(45600)

messi = Checking(345678)

ronaldo = Credit_card(123456)


x = input('enter processing service-')

if x == 'Savings':
   print(luci.withdraw())

elif x== 'Checking':
    print(messi.withdraw())

elif x == 'Credit_card':
    print(ronaldo.withdraw())

else:
    print('invalid process')
# Out:
# enter processing service-Credit_card
# Hello!!! Welcome to the ABC bank Credit Card service
# Enter amount to be Withdrawn: 3456
#
#  You Withdrew: 3456.0
#
#  Net Available Balance= 120000.0
# None

# %%
#17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and

class Employee:

  def __init__(self):
    pass

class manager(Employee):

  def __init__(self,salary):
    self.salary = salary

  def calculate_salary(self,hours_worked):
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('manager Salary-',self.salary)

class developer(Employee):

  def __init__(self,salary):
    self.salary = salary

  def calculate_salary(self,hours_worked):
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('developer Salary-',self.salary)

class designer(Employee):

  def __init__(self,salary):
    self.salary = salary

  def calculate_salary(self,hours_worked):
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('Designer Salary-',self.salary)





s = manager(50000)
e = developer(33000)
d = designer(23000)
s.calculate_salary(56)
e.calculate_salary(57)
d.calculate_salary(55)
# Out:
# manager Salary- 56000.0
# developer Salary- 37620.0
# Designer Salary- 25300.0

# %%
#20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., mammals, birds, reptiles) and their behavior (e.g., eating, sleeping, making sounds).

class zoo:
  def __init__(self):
    pass

class animal(zoo):
  def __init__(self,name):
    self.name = name

  def mammals(self):
    print( self.name,'is eating')

class animal2(zoo):

  def __init__(self,name):
    self.name = name

  def birds(self):
    print( self.name,'is making sound')

class animal3(zoo):

  def __init__(self,name):
    self.name = name

  def reptailes(self):
    print( self.name,'is sleeping')

a=animal('monkey')
b=animal2('crow')
c=animal3('snakes')

a.mammals()
b.birds()
c.reptailes()
# Out:
# monkey is eating
# crow is making sound
# snakes is sleeping

# %% [markdown]
# #Abstraction:

# %%
#3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of
#   using these classes.

from abc import ABC, abstractmethod

import math

class Shape(ABC):

    @abstractmethod
    def calculate_area(self):
        pass


class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2


class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

circle = Circle(5)
print('Area of Circle:',circle.calculate_area())

rectangle = Rectangle(5,7)
print('Area of rectangle:',rectangle.calculate_area())
# Out:
# Area of Circle: 78.53981633974483
# Area of rectangle: 35

# %%
#4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide
#   an example.

import abc


class AbstractClass(metaclass=abc.ABCMeta):
    def abstractfunc(self):
        return None


AbstractClass.register(dict)
print(issubclass(dict, AbstractClass))
# Out:
# True

# %%
#6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and
#   providing methods to deposit and withdraw funds.

from abc import ABC , abstractmethod
class BankAccount:

    @abstractmethod
    def account_balance(self):
        pass

class Savings(BankAccount):

    def __init__(self,balance):
     self.balance= balance

    def deposit(self):
      print("Hello!!! Welcome to the ABC bank")
      amount = float(input("Enter amount to deposit: "))
      if self.balance>=amount:
          self.balance+=amount
          print("\n You deposit:", amount)
      else:
          print("\n Insufficient balance  ")
      print("\n Net Available Balance=",self.balance)

    def withdraw(self):
      print("Hello!!! Welcome to the ABC bank")
      amount = float(input("Enter amount to be Withdrawn: "))
      if self.balance>=amount:
          self.balance-=amount
          print("\n You Withdrew:", amount)
      else:
          print("\n Insufficient balance  ")
      print("\n Net Available Balance=",self.balance)

a = Savings(234567)
x=input('deposit or withdraw-')

if x=='deposit':
 print(a.deposit())

elif x=='withdraw':
  print(a.withdraw())

else:
  print('invalid process')
# Out:
# deposit or withdraw-deposit
# Hello!!! Welcome to the ABC bank
# Enter amount to deposit: 3456
#
#  You deposit: 3456.0
#
#  Net Available Balance= 238023.0
# None

# %%
#8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class.

from abc import ABC,abstractmethod

class Animal(ABC):
    @abstractmethod
    def eat(self):
        print('eating')


    def sleep(self):
      print('sleeping')

c=Animal()

c.sleep()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-0ac6f80023c5> in <cell line: 14>()
#      12       print('sleeping')
#      13
# ---> 14 c=Animal()
#      15
#      16 c.sleep()
#
# TypeError: Can't instantiate abstract class Animal with abstract method eat

# %%
# 11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods

from abc import ABC,abstractmethod

class vehicle:

  def start(self):
    print('Vehicle is starting')

  def stop(self):
    print('Engine stop')

c1=vehicle()
c1.start()
c1.stop()
# Out:
# Vehicle is starting
# Engine stop

# %%
# 13. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and


from abc import ABC,abstractmethod

class Employee(ABC):

  def information(self):
    pass

class manager(Employee):


  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('manager Salary-',self.salary)

class developer(Employee):

  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('developer Salary-',self.salary)

class designer(Employee):

  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('Designer Salary-',self.salary)





s = manager()
e = developer()
d = designer()
s.get_salary(34567,56)
e.get_salary(23456,57)
d.get_salary(12345,55)
# Out:
# manager Salary- 38715.04
# developer Salary- 26739.84
# Designer Salary- 13579.5

# %%
#14. Discuss the differences between abstract classes and concrete classes in Python, including their instantiation.

from abc import ABC, abstractmethod

# Abstract base class
class Car(ABC):
  def __init__(self, brand):
    self.brand = brand

  #abstract method
  @abstractmethod
  def printDetails(self):
    pass

  #concrete method
  def accelerate(self):
    print("speed up ...")

  def break_applied(self):
    print("Car stop")

class Hatchback(Car):

  def printDetails(self):
    print("Brand:", self.brand);

  def Sunroof(self):
    print("Not having this feature")

c2=Hatchback('tesla')
c2.printDetails()
# Out:
# Brand: tesla

# %%
#16. Create a Python class for a computer system, demonstrating abstraction by defining common methods


from abc import ABC,abstractmethod

class computer(ABC):

  @abstractmethod
  def power_on(self):
    pass

  @abstractmethod
  def shutdown(self):
    pass

class engine(computer):

  def power_on(self):
    print('computer is starting')

  def shutdown(self):
    print('computer shuting down')


a=engine()
a.power_on()
a.shutdown()
# Out:
# computer is starting
# computer shuting down

# %%
# 19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class.

from abc import ABC,abstractmethod

class library(ABC):

  @abstractmethod
  def add_book():
    pass

  def borrow_book():
    pass

class books(library):

  def __init__(self,name1,name2):
    self.name1 = name1
    self.name2 = name2

  def add_book(self):
     print(self.name1,'book is added')

  def borrow_book(self):
     print(self.name2,'book is borrowed')

c3=books('titanic','social media')
c3.add_book()
c3.borrow_book()
# Out:
# titanic book is added
# social media book is borrowed

# %%
#20. Describe the concept of method abstraction in Python and how it relates to polymorphism.

from abc import ABC,abstractmethod

class Employee(ABC):

  def information(self):
    pass

class manager(Employee):


  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('manager Salary-',self.salary)

class developer(Employee):

  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('developer Salary-',self.salary)

class designer(Employee):

  def get_salary(self,salary,hours_worked):
      self.salary = salary
      overtime = 0
      if hours_worked > 50:
          self.overtime = hours_worked - 50
      self.salary = self.salary + (self.overtime * (self.salary / 50))
      print('Designer Salary-',self.salary)





s = manager()
e = developer()
d = designer()
s.get_salary(34567,56)
e.get_salary(23456,57)
d.get_salary(12345,55)
# Out:
# manager Salary- 38715.04
# developer Salary- 26739.84
# Designer Salary- 13579.5

# %% [markdown]
# # Composition:

# %%
#3. Create a Python class called `Author` with attributes for name and birthdate. Then, create a `Book` class
#   that contains an instance of `Author` as a composition. Provide an example of creating a `Book` object.


class Author:
  def __init__(self,name,birthdate):
    self.name = name
    self.birthdate = birthdate

  def m1(self):
    print('Author name-',self.name,'\nAuthor birthdate-',self.birthdate)

class Book:
  def __init__(self,title,published_year):
    self.title = title
    self.published_year = published_year
    self.obj1 = Author('luci',1956)

  def m2(self):
    print('title of book-',self.title)
    self.obj1.m1()
    print('published year-',self.published_year)

obj2=Book('Arther',1980)
obj2.m2()
# Out:
# title of book- Arther
# Author name- luci
# Author birthdate- 1956
# published year- 1980

# %%
#5. How can you implement composition in Python classes? Provide examples of using composition to create
#   complex objects.


class data:
  def __init__(self,mentor_name):
    self.mentor_name = mentor_name

class webdev:
  def __init__(self,mentor,lecture_name):
    self.mentor = mentor
    self.lecture_name = lecture_name

d = data('luci')
w= webdev(d,'css')


w.mentor.mentor_name
# Out:
# 'luci'

# %%
# 6. Create a Python class hierarchy for a music player system, using composition to represent playlists and songs.

class music:
    def __init__(self,song_name):
      self.song_name = song_name

    def m2(self):
      print('song names--',self.song_name)

class player_system:

    def __init__(self,playlist):
      self.obj = music('mammao,fake love,loveshot,exo')
      self.playlist = playlist

    def m3(self):
      self.obj.m2()
      print('Playlists--',self.playlist)


a1 = player_system('mammao,fake love')
a1.m3()
# Out:
# song names-- mammao,fake love,loveshot,exo
# Playlists-- mammao,fake love

# %%
#7. Explain the concept of "has-a" relationships in composition and how it helps design software systems.

class A:
    def __init__(self):
        print('Class - A Constructor')

    def m1(self):
        print('M1 method of Class - A.')


class B:
    def __init__(self):
        print('Class - B Constructor.')

    def m2(self):
        obj = A()

        obj.m1()
        print('M2 method of Class - B.')


obj = B()

obj.m2()
# Out:
# Class - B Constructor.
# Class - A Constructor
# M1 method of Class - A.
# M2 method of Class - B.

# %%
#8. Create a Python class for a computer system, using composition to represent components like CPU, RAM,
#   and storage devices.


class CPU:
    def __init__(self,name,model,price):
      self.name = name
      self.model = model
      self.price = price

    def m2(self):
      print('CPU--','\n names--',self.name,'\n model--',self.model,'\n price--',self.price)

class  RAM:
    def __init__(self,model,capacity,price):
      self.model = model
      self.capacity = capacity
      self.price = price


    def m3(self):
      print('RAM--','\n model--',self.model,'\n capacity--',self.capacity,'\n price--',self.price)

class  Hard_disk:
    def __init__(self,model,capacity,price):
      self.model = model
      self.capacity = capacity
      self.price = price


    def m4(self):
      print('Hard disk--''\n model--',self.model,'\n capacity--',self.capacity,'\n price--',self.price)

class System:

    def __init__(self,name):
      self.name = name

      self.obj1 = CPU('intel','10th gen',12300)
      self.obj2 = RAM('DDR4','6GB',7800)
      self.obj3 = Hard_disk('infinix','1TB',6000)
    def m5(self):
      print('Computer systems feature-- ',self.name)
      self.obj1.m2()
      self.obj2.m3()
      self.obj3.m4()



a1 = System('CPU,RAM,Hard disk')
a1.m5()
# Out:
# Computer systems feature--  CPU,RAM,Hard disk
# CPU--
#  names-- intel
#  model-- 10th gen
#  price-- 12300
# RAM--
#  model-- DDR4
#  capacity-- 6GB
#  price-- 7800
# Hard disk--
#  model-- infinix
#  capacity-- 1TB
#  price-- 6000

# %%
#9. Describe the concept of "delegation" in composition and how it simplifies the design of complex systems.

class A:
  def spam(self, x):
    pass
  def foo(self):
    pass
class B:
  def __init__(self):
    self._a = A()
  def spam(self, x):
    return self._a.spam(x)
  def foo(self):
    return self._a.foo()
  def bar(self):
    pass

a=B()
a.spam('luci')

# %%
#10. Create a Python class for a car, using composition to represent components like the engine, wheels, and transmission.


class engine:
  def __init__(self):
    print('this car has super engine')

  def q2(self):
    print('A class engine')

class wheels:

  def __init__(self):
    print('This is a 4wheels car')

  def q3(self):
    print('BO motor wheels')

class transmission:

  def __init__(self):
    print('this has better  transmission ')

  def q4(self):
    print('Automatic transmission')

class Car:
  def __init__(self):

   self.obj=engine()
   self.obj1=wheels()
   self.obj2=transmission()
  def q5(self):
    print('This car has component-')
    self.obj.q2()
    self.obj1.q3()
    self.obj2.q4()

obj3=Car()
obj3.q5()
# Out:
# this car has super engine
# This is a 4wheels car
# this has better  transmission
# This car has component-
# A class engine
# BO motor wheels
# Automatic transmission

# %%
#12. Create a Python class for a university course, using composition to represent students, instructors, and course materials.


class students:
    def __init__(self,name,department):
      self.name = name
      self.department = department

    def q2(self):
      print('Students','\n Names--',self.name,'\n Department --',self.department)

class  instructors:
    def __init__(self,name,major):
      self.name = name
      self.major = major


    def q3(self):
      print('Instructors--','\n Names--',self.name,'\n Major--',self.major)

class  course_materials:
    def __init__(self,materials):
      self.materials = materials


    def q4(self):
      print('course_materials--''\n materials--',self.materials)

class University_System:

    def __init__(self,name):
      self.name = name

      self.obj1 = students('messi,ronaldo,ronaldinho,bape','Mathmetics')
      self.obj2 = instructors('Atanu,mukesh,alex','physic,english,sicene')
      self.obj3 = course_materials('Quantum physics,Thermodynamics,English,')
    def q5(self):
      print('University-- ',self.name)
      self.obj1.q2()
      self.obj2.q3()
      self.obj3.q4()



a1 =University_System('Seol')
a1.q5()
# Out:
# University--  Seol
# Students
#  Names-- messi,ronaldo,ronaldinho,bape
#  Department -- Mathmetics
# Instructors--
#  Names-- Atanu,mukesh,alex
#  Major-- physic,english,sicene
# course_materials--
#  materials-- Quantum physics,Thermodynamics,English,
